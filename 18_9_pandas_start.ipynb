# %%
#import pandas as pd
with open('test.txt', mode='wb+') as file:
    file.write(b'\xd1\xe5\xea\xf0\xe5\xf2\xed\xee\xe5 \xf1\xeb\xee\xe2\xee: \xef\xf3\xf5\xee\xe2\xe8\xf7\xee\xea')

# %%
import os
with open('test.txt', mode ='r', encoding = 'cp1251') as file:
    print(file.readlines())
# Out:
# ['Секретное слово: пуховичок']

# %%
# %pip install gspread-pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gspread_pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('productstar_df.csv', index_col=0)

# %%
len(df)
# Out:
# 474959

# %%
df
# Out:
#                        shipped_at  order_id    item_total order_state  \
# id
# 0       2018-05-20 01:42:14+00:00       557   3243.119268    complete
# 1                             NaN      1097   4590.108329    canceled
# 2       2017-06-14 03:26:44+00:00      3103  12018.548693    complete
# 3       2017-06-12 00:16:40+00:00      3112   2467.022803    complete
# 4       2017-05-31 05:23:53+00:00      3201   1461.915164    complete
# ...                           ...       ...           ...         ...
# 474954  2019-01-05 23:01:39+00:00   3642207   2261.725542    complete
# 474955                        NaN   3642208   3234.739393    canceled
# 474956  2019-01-23 05:19:03+00:00   3642213   3621.669987    complete
# 474957  2018-12-26 09:02:33+00:00   3642227   3089.668218    complete
# 474958  2018-12-21 09:49:58+00:00   3642244   4110.140282    complete
#
#         store_id  retailer_id  promo_total  total_weight  \
# id
# 0             75            8       -200.0          6085
# ...

# %%
df['item_total'].sum() / df['item_count'].sum()
# Out:
# 277.3234135925197
